# %% [markdown]
# <a href="https://colab.research.google.com/github/tabatalond/tabatalond/blob/main/ols_tankaiki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import  numpy  as np

# %%
pd.read_csv("/content/data.csv", encoding="cp932")
# Out:
#     小テスト  期末テスト  睡眠時間 通学方法
# 0    4.2     67   7.2   バス
# 1    7.2     71   7.9  自転車
# 2    0.0     19   5.3   バス
# 3    3.0     35   6.8   徒歩
# 4    1.5     35   7.5   徒歩
# 5    0.9     40   7.6   バス
# 6    1.9     23   4.3   徒歩
# 7    3.5     37   4.2  自転車
# 8    4.0     39   4.7  自転車
# 9    5.4     55   7.5   徒歩
# 10   4.2     40   4.4   バス
# 11   6.9     70   5.7   バス
# 12   2.0     29   7.8   バス
# 13   8.8     88   6.1  自転車
# 14   0.3     47   6.8   徒歩
# 15   6.7     77   5.3   バス
# 16   4.2     52   6.7   徒歩
# 17   5.6     55   7.3   徒歩
# 18   1.4     18   4.1   徒歩
# 19   2.0     60   7.0  自転車

# %%
import statsmodels.api as smf

# %%
formula =  "期末テスト" ~ "小テスト"
model = smf.ols(formula,df).fit()
# Out:
#   File "/tmp/ipython-input-79334730.py", line 1
#     formula =  "期末テスト" ~ "小テスト"
#                        ^
# SyntaxError: invalid syntax
